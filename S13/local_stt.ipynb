# %% [markdown]
# # Local sst

# %%
import whisper

model = whisper.load_model("small")

# %%
result = model.transcribe(
    "audio/speech.mp3", 
    language="en"
)
print(result["text"])
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:27<00:00, 17.5MiB/s]
# /home/santi/anaconda3/envs/lab/lib/python3.11/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Today is a wonderful day to build something people love.
