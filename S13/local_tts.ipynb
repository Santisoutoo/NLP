# %% [markdown]
# # Local tts

# %%
#!pip install pyttsx3

# %%
import pyttsx3

# %%
engine = pyttsx3.init()
engine.setProperty("rate", 150)
engine.setProperty("volume", 0.9)

# %%
engine.say("ROGER.")
engine.runAndWait()
