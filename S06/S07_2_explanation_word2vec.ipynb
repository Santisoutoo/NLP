# %% [markdown]
# # Word2vec with gensim
#
# In this Jupyter notebook you will use the [Gensim] library (https://radimrehurek.com/gensim/index.html) to experiment with Word2VEC.This notebook is focused on the intuition of the concepts and not on the implementation details.This notebook is inspired by this [Guide] (https://radicrehurek.com/gensim/auto_examples/ttorials/run_word2vec.html).
#
# ## 1. Installation and loading the model

# %%
#!pip install --upgrade gensim

# %%
import gensim.downloader as api

# %%
model = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %% [markdown]
# ## 2. Similarity of words
#
# In this section we will see how to achieve the similarity between two words using a Word Embedding already trained.

# %%
model.similarity("king", "queen")
# Out:
# 0.6510957

# %%
model.similarity("king", "man")
# Out:
# 0.22942673

# %%
model.similarity("king", "potato")
# Out:
# 0.09978465

# %%
model.similarity("king", "king")
# Out:
# 1.0

# %% [markdown]
# Now we will see how to find the words with greater similarity to the set of specified words.

# %%
model.most_similar(["king", "queen"], topn=5)
# Out:
# [('monarch', 0.7042067050933838),
#  ('kings', 0.6780861616134644),
#  ('princess', 0.6731551885604858),
#  ('queens', 0.6679497957229614),
#  ('prince', 0.6435247659683228)]

# %%
model.most_similar(["tomato", "carrot"], topn=5)
# Out:
# [('carrots', 0.7536594867706299),
#  ('tomatoes', 0.7129638195037842),
#  ('celery', 0.7025030851364136),
#  ('broccoli', 0.6796350479125977),
#  ('cherry_tomatoes', 0.662927508354187)]

# %% [markdown]
# But you can even do interesting things such as seeing what word does not correspond to a list.

# %%
model.doesnt_match(["summer", "fall", "spring", "air"])
# Out:
# 'air'

# %% [markdown]
# ## Exercises
#
# 1. Use the Word2VEC model to make a ranking of the following 15 words according to its similarity with the words "man" and "Woman".For each pair, it prints its similarity.

# %%
words = [
"wife",
"husband",
"child",
"queen",
"king",
"man",
"woman",
"birth",
"doctor",
"nurse",
"teacher",
"professor",
"engineer",
"scientist",
"president"
]

# %%
# Compute similarity with "man"
similarity_man = [(w, model.similarity("man", w)) for w in words if w in model]
similarity_man_sorted = sorted(similarity_man, key=lambda x: x[1], reverse=True)

print("Ranking by similarity with 'man':")
for word, sim in similarity_man_sorted:
    print(f"man -> '{word}': <{sim:.4f}>")
# Out:
# Ranking by similarity with 'man':
# man -> 'Man': <1.0000>
# man -> 'Woman': <0.7664>
# man -> 'Husband': <0.3450>
# man -> 'Wife': <0.3292>
# man -> 'Child': <0.3163>
# man -> 'Doctor': <0.3145>
# man -> 'Nurse': <0.2547>
# man -> 'Teacher': <0.2500>
# man -> 'King': <0.2294>
# man -> 'Queen': <0.1666>
# man -> 'Scientist': <0.1582>
# man -> 'Engineer': <0.1513>
# man -> 'Birth': <0.1108>
# man -> 'Professor': <0.0942>
# man -> 'President': <0.0284>

# %%
# Compute similarity with "woman"
similarity_woman = [(w, model.similarity("woman", w)) for w in words if w in model]
similarity_woman_sorted = sorted(similarity_woman, key=lambda x: x[1], reverse=True)

print("Ranking by similarity with 'woman':")
for word, sim in similarity_woman_sorted:
    print(f"woma' -> '{word}': <{sim:.4f}>")
# Out:
# Ranking by similarity with 'woman':
# woma' -> 'woman': <1.0000>
# woma' -> 'man': <0.7664>
# woma' -> 'husband': <0.4928>
# woma' -> 'child': <0.4750>
# woma' -> 'wife': <0.4448>
# woma' -> 'nurse': <0.4414>
# woma' -> 'doctor': <0.3795>
# woma' -> 'queen': <0.3162>
# woma' -> 'teacher': <0.3136>
# woma' -> 'birth': <0.2147>
# woma' -> 'scientist': <0.1549>
# woma' -> 'professor': <0.1308>
# woma' -> 'king': <0.1285>
# woma' -> 'engineer': <0.0944>
# woma' -> 'president': <0.0627>

# %% [markdown]
# ** 2. Complete the following analogies on your own (without using the model) **
#
# a. king is to throne as judge is to **dais**
#
# b. giant is to dwarf as genius is to **fool**
#
# c. French is to France as Spaniard is to **Spain**
#
# d. bad is to good as sad is to **happy**
#
# e. nurse is to hospital as teacher is to **school**
#
# f. universe is to planet as house is to **room**

# %% [markdown]
# **3. Ahora completa las analogías usando un modelo word2vec**
#
# Aquí hay un ejemplo de cómo hacerlo. Puedes resolver analogías como "A es a B como C es a _" haciendo A + C - B.
# v(D) ≈ v(C) + v(A) − v(B) -> "D" = palabra más similar a (v(C) + v(A) − v(B)

# %%
model.most_similar(positive=["judge", "king"], negative=["throne"], topn=1)
# Out:
# [('appeals_court', 0.5385673642158508)]

# %%
model.most_similar(positive=["genius", "giant"], negative=["dwarf"], topn=1)
# Out:
# [('wizardry', 0.5062874555587769)]

# %%
model.most_similar(positive=["Spaniard", "French"], negative=["France"], topn=1)
# Out:
# [('Frenchman', 0.6701309084892273)]

# %%
model.most_similar(positive=["sad", "good"], negative=["bad"], topn=1)
# Out:
# [('wonderful', 0.6414927840232849)]

# %%
model.most_similar(positive=["teacher", "nurse"], negative=["hospital"], topn=1)
# Out:
# [('guidance_counselor', 0.6577334403991699)]

# %%
model.most_similar(positive=["house", "universe"], negative=["planet"], topn=1)
# Out:
# [('houses', 0.5309091210365295)]
